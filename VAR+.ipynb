# %%
#The following code is used to implement the VAR model which will be used for each financial time series forecast (VAR(1)).
#Hereby, the logarithmic returns are being analyzed, as the adjusted closing prices themselves are not stationary (refer to the visualization & model selection file
#for the associated Augmented Dickey-Fuller tests). On the foundation of the log returns, the code generates out-of-sample forecasts of the adusted closing prices
#ten steps into the future. The evaluation of the forecasts (the results are then being compared to the ARIMA and the video prediction neural network) is performed on the basis of
#the MAPE, the RRMSE and the price movement direction metric.

#Import all necessary libraries

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import yfinance as yf
import numpy as np
import pandas as pd
from statsmodels.tsa.api import VAR
from sklearn.metrics import mean_absolute_percentage_error

#Download the dataset
#Use the code below (commented out) if the download should happen directly through Yahoo Finance

'''
ticker_list = ['AAPL', 'ACN', 'ADBE',
              'AMD', 'GOOG', 'MU',
              'PYPL', 'QCOM', 'STX']
stock_prices = yf.download(ticker_list, start = '2023-07-17', end = '2023-12-16', interval = '1d')['Adj Close']
'''

stock_prices = pd.read_csv('https://github.com/sch-wm/time_series/raw/main/yfinance_stock_prices_for_baselines.csv', index_col = 0)
stock_prices.index = pd.to_datetime(stock_prices.index)

#Inspect the data

stock_prices.head(10)
stock_prices.shape

#Preprocess the data (insert missing dates and remove the related nans through linear interpolation)

dates = pd.date_range(start = pd.to_datetime('2023-07-17').tz_localize("GMT+0") , end = pd.to_datetime('2023-12-16').tz_localize("GMT+0"), freq = 'B')
stock_prices = stock_prices.reindex(dates)
stock_prices.interpolate(inplace = True)

#Inspect the data

stock_prices.shape #Dataframe has 110 elements, starts at a Monday, ends at a Friday

#Use ln on the prices and difference to get log returns

log_stock_prices = np.log(stock_prices) #Dataframe has 110 elements, index: 0 - 109, data starts at Monday, ends at Friday
log_returns_stock_prices = log_stock_prices.diff()
log_returns_stock_prices.dropna(inplace = True) #Dataframe has 109 elements after differencing, index: 0 - 108, data starts at Tuesday, ends at Friday

#Define and initialize all parameters, necessary for looping

number_of_assets = 9
timesteps_forecast = 10

#Compute log returns forecasts with VAR (manual differencing is required)

VAR_model_before_fit = VAR(log_returns_stock_prices.iloc[:99, :]) #Data sequence starts at Tu, ends at Fr
VAR_model = VAR_model_before_fit.fit(maxlags = 1)
forecasts_list = VAR_model.forecast(log_returns_stock_prices.values, steps = 10) #Forecasts start at Mo, ends at Fr, results are stored in np.array of shape 10, 9

#Inspect the forecasts

print(forecasts_list, 'Forecasts in list of lists (log returns)')
print(len(forecasts_list), 'timesteps')
print(len(forecasts_list[0]), 'assets per timestep')

#Prepare one list with 10 * 9 elements for forecasts

forecasts_flat = []
for asset in range(number_of_assets):
  for timestep in range(timesteps_forecast):
    forecasts_flat.append(forecasts_list[timestep][asset])

#Inspect the forecasts of the log returns

print(forecasts_flat, 'Forecasts in one list (log returns)')
print(len(forecasts_flat), 'elements in one list')

#Transform the forecasts of the logarithmically-modified adjusted closing prices back into
#forecasts of adjusted closing prices

forecasts_flat_prices = []
index_shift = 0
for asset in range(number_of_assets):
  exponent = log_stock_prices.iloc[99, asset] #Computation starts from ln price of Fr (add up the log returns)
  print(log_stock_prices.iloc[99, asset], 'Last observed ln price - asset', asset)
  print(log_stock_prices.iloc[100:110, asset], 'Test data ln prices - asset', asset)
  for timestep in range(timesteps_forecast):
    exponent = exponent + forecasts_flat[timestep + index_shift]
    print('Forecast ln price', 1 + timestep + asset * timesteps_forecast, '-', exponent, '- asset', asset)
    price = np.exp(exponent)
    print('Forecast price', 1 + timestep + asset * timesteps_forecast, '-', price, '- asset', asset)
    forecasts_flat_prices.append(price)
  index_shift = index_shift + timesteps_forecast

print(forecasts_flat_prices, 'Forecasts of adjusted closing prices')

#Put test data in a list

test_flat = []
for asset in range(number_of_assets):
  for timestep in range(timesteps_forecast):
    test_flat.append(stock_prices.iloc[timestep + 100, asset]) #Appending starts at Mo

#Inspect the list

print(test_flat, 'Test data prices')
stock_prices.tail(10)

#Compute the MAPE

MAPE_list = []
MAPE_assets_averages_list = []
total_errors = number_of_assets * timesteps_forecast
for error in range(total_errors):
  MAPE = np.abs(test_flat[error] - forecasts_flat_prices[error]) / test_flat[error]
  MAPE_list.append(MAPE)
print(MAPE_list, 'MAPE')
index_shift = 0
for asset in range(number_of_assets):
  MAPE_asset_average = mean_absolute_percentage_error(test_flat[index_shift : index_shift + 10], forecasts_flat_prices[index_shift : index_shift + 10])
  MAPE_assets_averages_list.append(MAPE_asset_average)
  index_shift = index_shift + 10
print(MAPE_assets_averages_list, 'average MAPE (over all timesteps/per asset)')

#Compute the RRMSE

RRMSE_assets = []
index_shift = 0
for asset in range(number_of_assets):
  RRMSE_asset_sum = 0.00
  for timestep in range(timesteps_forecast):
    RRMSE_asset_sum = RRMSE_asset_sum + (((forecasts_flat_prices[timestep + index_shift] - test_flat[timestep + index_shift])
                                                     / test_flat[timestep + index_shift]) ** 2)
  RRMSE_asset = np.sqrt(RRMSE_asset_sum / timesteps_forecast)
  RRMSE_assets.append(RRMSE_asset)
  index_shift = index_shift + 10
print(RRMSE_assets, 'Individual RRMSE values (for each asset)')
RRMSE_assets = sum(RRMSE_assets)
RRMSE_assets = RRMSE_assets / number_of_assets
print(RRMSE_assets, 'RRMSE')

#Compute the price movement direction metric

price_movement_direction_assets = []
weight_lambda = 0.60
index_shift = 0
for asset in range(number_of_assets):
  price_movement_direction_asset_sum = 0.00
  if (((forecasts_flat_prices[index_shift] - stock_prices.iloc[99, asset]) / (test_flat[index_shift] - stock_prices.iloc[99, asset])) > 0):
      price_movement_direction_asset_sum = price_movement_direction_asset_sum + (1 * (weight_lambda ** 0))
  for timestep in range(timesteps_forecast - 1):
    if (((forecasts_flat_prices[timestep + 1 + index_shift] - forecasts_flat_prices[timestep + index_shift]) / (test_flat[timestep + 1 + index_shift] - test_flat[timestep + index_shift])) > 0):
      price_movement_direction_asset_sum = price_movement_direction_asset_sum + (1 * (weight_lambda ** (timestep + 1)))
  price_movement_direction_assets.append(price_movement_direction_asset_sum)
  index_shift = index_shift + 10
print(price_movement_direction_assets, 'Individual price movement direction metric values (for each asset)')
price_movement_direction_assets_sum = sum(price_movement_direction_assets)
# Freq: B, Name: ACN, dtype: float64 Test data ln prices - asset 1
# Forecast ln price 11 - 5.808765685011714 - asset 1
# Forecast price 11 - 333.2075886227937 - asset 1
# Forecast ln price 12 - 5.810484909538729 - asset 1
# Forecast price 12 - 333.7809400003943 - asset 1
# Forecast ln price 13 - 5.810463079667874 - asset 1
# Forecast price 13 - 333.7736536851099 - asset 1
# Forecast ln price 14 - 5.811301101135262 - asset 1
# Forecast price 14 - 334.0534804061701 - asset 1
# Forecast ln price 15 - 5.811761019831409 - asset 1
# Forecast price 15 - 334.2071531831046 - asset 1
# Forecast ln price 16 - 5.812315495008321 - asset 1
# Forecast price 16 - 334.3925141377662 - asset 1
# Forecast ln price 17 - 5.81285983007838 - asset 1
# Forecast price 17 - 334.57458525972925 - asset 1
# Forecast ln price 18 - 5.813399834262025 - asset 1
# Forecast price 18 - 334.75530572602327 - asset 1
# Forecast ln price 19 - 5.813943884560022 - asset 1
# Forecast price 19 - 334.93747900107826 - asset 1
# Forecast ln price 20 - 5.8144853656932876 - asset 1
# Forecast price 20 - 335.1188904377836 - asset 1
# 6.417499913793529 Last observed ln price - asset 2
# 2023-12-04 00:00:00+00:00    6.404501
# 2023-12-05 00:00:00+00:00    6.400623
# 2023-12-06 00:00:00+00:00    6.389737
# 2023-12-07 00:00:00+00:00    6.411457
# 2023-12-08 00:00:00+00:00    6.413475
# 2023-12-11 00:00:00+00:00    6.438072
# 2023-12-12 00:00:00+00:00    6.451512
# 2023-12-13 00:00:00+00:00    6.436567
# 2023-12-14 00:00:00+00:00    6.370996
# 2023-12-15 00:00:00+00:00    6.371065
# Freq: B, Name: ADBE, dtype: float64 Test data ln prices - asset 2
# Forecast ln price 21 - 6.41371889132614 - asset 2
# Forecast price 21 - 610.1585804462023 - asset 2
# Forecast ln price 22 - 6.417405076858694 - asset 2
# Forecast price 22 - 612.4118886826288 - asset 2
# Forecast ln price 23 - 6.419104676209253 - asset 2
# Forecast price 23 - 613.4536285503423 - asset 2
# Forecast ln price 24 - 6.420493574693063 - asset 2
# Forecast price 24 - 614.3062453269371 - asset 2
# Forecast ln price 25 - 6.421951711808318 - asset 2
# Forecast price 25 - 615.2026414387776 - asset 2
# Forecast ln price 26 - 6.423407009881744 - asset 2
# Forecast price 26 - 616.098596440296 - asset 2
# Forecast ln price 27 - 6.424888281758278 - asset 2
# Forecast price 27 - 617.0118822096459 - asset 2
# Forecast ln price 28 - 6.426348491236468 - asset 2
# Forecast price 28 - 617.9135069284799 - asset 2
# Forecast ln price 29 - 6.427816941567917 - asset 2
# Forecast price 29 - 618.8215487665336 - asset 2
# Forecast ln price 30 - 6.429283148377935 - asset 2
# Forecast price 30 - 619.7295346203791 - asset 2
# 4.79900849788169 Last observed ln price - asset 3
# 2023-12-04 00:00:00+00:00    4.775504
# 2023-12-05 00:00:00+00:00    4.773900
# 2023-12-06 00:00:00+00:00    4.760634
# 2023-12-07 00:00:00+00:00    4.854917
# 2023-12-08 00:00:00+00:00    4.859192
# 2023-12-11 00:00:00+00:00    4.900895
# 2023-12-12 00:00:00+00:00    4.924424
# 2023-12-13 00:00:00+00:00    4.928630
# 2023-12-14 00:00:00+00:00    4.927254
# 2023-12-15 00:00:00+00:00    4.935552
# Freq: B, Name: AMD, dtype: float64 Test data ln prices - asset 3
# Forecast ln price 31 - 4.796264004973942 - asset 3
# Forecast price 31 - 121.05730214869071 - asset 3
# Forecast ln price 32 - 4.798353023507294 - asset 3
# Forecast price 32 - 121.31045742744743 - asset 3
# Forecast ln price 33 - 4.798795976299288 - asset 3
# Forecast price 33 - 121.36420413601144 - asset 3
# Forecast ln price 34 - 4.799036057286064 - asset 3
# Forecast price 34 - 121.39334487182805 - asset 3
# Forecast ln price 35 - 4.799349640767609 - asset 3
# Forecast price 35 - 121.43141778875629 - asset 3
# Forecast ln price 36 - 4.799666006456357 - asset 3
# Forecast price 36 - 121.46984060038989 - asset 3
# Forecast ln price 37 - 4.799993395246437 - asset 3
# Forecast price 37 - 121.50961497502215 - asset 3
# Forecast ln price 38 - 4.800308928021714 - asset 3
# Forecast price 38 - 121.54796129049956 - asset 3
# Forecast ln price 39 - 4.800629290806724 - asset 3
# Forecast price 39 - 121.58690697193131 - asset 3
# Forecast ln price 40 - 4.800948501205465 - asset 3
# Forecast price 40 - 121.6257249722125 - asset 3
# 4.891615035570494 Last observed ln price - asset 4
# 2023-12-04 00:00:00+00:00    4.871232
# 2023-12-05 00:00:00+00:00    4.884615
# 2023-12-06 00:00:00+00:00    4.877337
# 2023-12-07 00:00:00+00:00    4.929372
# 2023-12-08 00:00:00+00:00    4.916212
# 2023-12-11 00:00:00+00:00    4.901913
# 2023-12-12 00:00:00+00:00    4.894012
# 2023-12-13 00:00:00+00:00    4.896479
# 2023-12-14 00:00:00+00:00    4.890714
# 2023-12-15 00:00:00+00:00    4.895508
# Freq: B, Name: GOOG, dtype: float64 Test data ln prices - asset 4
# Forecast ln price 41 - 4.89568152186259 - asset 4
# Forecast price 41 - 133.7111026087639 - asset 4
# Forecast ln price 42 - 4.896349321696026 - asset 4
# Forecast price 42 - 133.80042468212793 - asset 4
# Forecast ln price 43 - 4.897711363308016 - asset 4
# Forecast price 43 - 133.98279059503474 - asset 4
# Forecast ln price 44 - 4.898228519349301 - asset 4
# Forecast price 44 - 134.05209852458174 - asset 4
# Forecast ln price 45 - 4.899067077994224 - asset 4
# Forecast price 45 - 134.16455621526413 - asset 4
# Forecast ln price 46 - 4.899819963068839 - asset 4
# Forecast price 46 - 134.26560474137133 - asset 4
# Forecast ln price 47 - 4.900601517917941 - asset 4
# Forecast price 47 - 134.3705816931039 - asset 4
# Forecast ln price 48 - 4.9013746931798785 - asset 4
# Forecast price 48 - 134.47451387652012 - asset 4
# Forecast ln price 49 - 4.902148449461638 - asset 4
# Forecast price 49 - 134.57860464161706 - asset 4
# Forecast ln price 50 - 4.902923350945333 - asset 4
# Forecast price 50 - 134.68293021782893 - asset 4
# 4.326634693346999 Last observed ln price - asset 5
# 2023-12-04 00:00:00+00:00    4.304799
# 2023-12-05 00:00:00+00:00    4.296690
# 2023-12-06 00:00:00+00:00    4.289061
# 2023-12-07 00:00:00+00:00    4.296147
# 2023-12-08 00:00:00+00:00    4.313778
# 2023-12-11 00:00:00+00:00    4.350836
# 2023-12-12 00:00:00+00:00    4.355581
# 2023-12-13 00:00:00+00:00    4.376221
# 2023-12-14 00:00:00+00:00    4.405856
# 2023-12-15 00:00:00+00:00    4.396321
# Freq: B, Name: MU, dtype: float64 Test data ln prices - asset 5
# Forecast ln price 51 - 4.330104526284703 - asset 5
# Forecast price 51 - 75.95222515819522 - asset 5
# Forecast ln price 52 - 4.333752656738588 - asset 5
# Forecast price 52 - 76.22981481761356 - asset 5
# Forecast ln price 53 - 4.334976001967959 - asset 5
# Forecast price 53 - 76.32312726293658 - asset 5
# Forecast ln price 54 - 4.336898951268826 - asset 5
# Forecast price 54 - 76.47003396895212 - asset 5
# Forecast ln price 55 - 4.338460295268383 - asset 5
# Forecast price 55 - 76.58952325530136 - asset 5
# Forecast ln price 56 - 4.3402182629637505 - asset 5
# Forecast price 56 - 76.72428358043106 - asset 5
# Forecast ln price 57 - 4.34190218954354 - asset 5
# Forecast price 57 - 76.85359048197638 - asset 5
# Forecast ln price 58 - 4.343603808711837 - asset 5
# Forecast price 58 - 76.98447735291519 - asset 5
# Forecast ln price 59 - 4.345303124077548 - asset 5
# Forecast price 59 - 77.11540947417755 - asset 5
# Forecast ln price 60 - 4.347001872666847 - asset 5
# Forecast price 60 - 77.24652049803902 - asset 5
# 4.08849417412446 Last observed ln price - asset 6
# 2023-12-04 00:00:00+00:00    4.091841
# 2023-12-05 00:00:00+00:00    4.059063
# 2023-12-06 00:00:00+00:00    4.086480
# 2023-12-07 00:00:00+00:00    4.068685
# 2023-12-08 00:00:00+00:00    4.076520
# 2023-12-11 00:00:00+00:00    4.078215
# 2023-12-12 00:00:00+00:00    4.075671
# 2023-12-13 00:00:00+00:00    4.122770
# 2023-12-14 00:00:00+00:00    4.125035
# 2023-12-15 00:00:00+00:00    4.115127
# Freq: B, Name: PYPL, dtype: float64 Test data ln prices - asset 6
# Forecast ln price 61 - 4.091205469252767 - asset 6
# Forecast price 61 - 59.81194972989944 - asset 6
# Forecast ln price 62 - 4.085335011398026 - asset 6
# Forecast price 62 - 59.46185481394654 - asset 6
# Forecast ln price 63 - 4.085137452140516 - asset 6
# Forecast price 63 - 59.45010873437088 - asset 6
# Forecast ln price 64 - 4.082536888029923 - asset 6
# Forecast price 64 - 59.29570576964781 - asset 6
# Forecast ln price 65 - 4.080333003343005 - asset 6
# Forecast price 65 - 59.16516876878679 - asset 6
# Forecast ln price 66 - 4.078116444984897 - asset 6
# Forecast price 66 - 59.0341709552268 - asset 6
# Forecast ln price 67 - 4.07588467932875 - asset 6
# Forecast price 67 - 58.9025674286892 - asset 6
# Forecast ln price 68 - 4.073668643208857 - asset 6
# Forecast price 68 - 58.772181734774776 - asset 6
# Forecast ln price 69 - 4.071439147546212 - asset 6
# Forecast price 69 - 58.64129537002004 - asset 6
# Forecast ln price 70 - 4.069216835955392 - asset 6
# Forecast price 70 - 58.51112083737895 - asset 6
# 4.850681873044665 Last observed ln price - asset 7
# 2023-12-04 00:00:00+00:00    4.852839
# 2023-12-05 00:00:00+00:00    4.858976
# 2023-12-06 00:00:00+00:00    4.852916
# 2023-12-07 00:00:00+00:00    4.875587
# 2023-12-08 00:00:00+00:00    4.875813
# 2023-12-11 00:00:00+00:00    4.899079
# 2023-12-12 00:00:00+00:00    4.903332
# 2023-12-13 00:00:00+00:00    4.918723
# 2023-12-14 00:00:00+00:00    4.937989
# 2023-12-15 00:00:00+00:00    4.949443
# Freq: B, Name: QCOM, dtype: float64 Test data ln prices - asset 7
# Forecast ln price 71 - 4.845373667602771 - asset 7
# Forecast price 71 - 127.15078524708449 - asset 7
# Forecast ln price 72 - 4.8482636821528695 - asset 7
# Forecast price 72 - 127.51878437178443 - asset 7
# Forecast ln price 73 - 4.849039756282954 - asset 7
# Forecast price 73 - 127.61778681308293 - asset 7
# Forecast ln price 74 - 4.849768675827708 - asset 7
# Forecast price 74 - 127.71084382356577 - asset 7
# Forecast ln price 75 - 4.850580628245471 - asset 7
# Forecast price 75 - 127.81458106113409 - asset 7
# Forecast ln price 76 - 4.851335084155862 - asset 7
# Forecast price 76 - 127.91104791266717 - asset 7
# Forecast ln price 77 - 4.852131464230873 - asset 7
# Forecast price 77 - 128.01295429531908 - asset 7
# Forecast ln price 78 - 4.85290212221427 - asset 7
# Forecast price 78 - 128.11164652461764 - asset 7
# Forecast ln price 79 - 4.853683100770743 - asset 7
# Forecast price 79 - 128.21173805296908 - asset 7
# Forecast ln price 80 - 4.8544608037550185 - asset 7
# Forecast price 80 - 128.31148748696071 - asset 7
# 4.348600327370448 Last observed ln price - asset 8
# 2023-12-04 00:00:00+00:00    4.341121
# 2023-12-05 00:00:00+00:00    4.320162
# 2023-12-06 00:00:00+00:00    4.331147
# 2023-12-07 00:00:00+00:00    4.343536
# 2023-12-08 00:00:00+00:00    4.366251
# 2023-12-11 00:00:00+00:00    4.383474
# 2023-12-12 00:00:00+00:00    4.391249
# 2023-12-13 00:00:00+00:00    4.424574
# 2023-12-14 00:00:00+00:00    4.423403
# 2023-12-15 00:00:00+00:00    4.411021
# Freq: B, Name: STX, dtype: float64 Test data ln prices - asset 8
# Forecast ln price 81 - 4.353787545084544 - asset 8
# Forecast price 81 - 77.77247253251677 - asset 8
# Forecast ln price 82 - 4.35751696586491 - asset 8
# Forecast price 82 - 78.0630603330056 - asset 8
# Forecast ln price 83 - 4.360047840116299 - asset 8
# Forecast price 83 - 78.26087834305035 - asset 8
# Forecast ln price 84 - 4.362956147955954 - asset 8
# Forecast price 84 - 78.48881636537924 - asset 8
# Forecast ln price 85 - 4.365676551068189 - asset 8
# Forecast price 85 - 78.70262828113457 - asset 8
# Forecast ln price 86 - 4.368500507715311 - asset 8
# Forecast price 86 - 78.92519520317522 - asset 8
# Forecast ln price 87 - 4.37127953927794 - asset 8
